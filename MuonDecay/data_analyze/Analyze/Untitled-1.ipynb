# %%
from data_analyze.FindPeaks.peaks import peaks_muon_decay
from data_analyze.Plots.plots import plots_MuonDecay
from data_analyze.Spectrums.contours import contours_muon_decay
from data_analyze.Spectrums.integral import simpson_integral_df, integral_rectangle_df
from data_analyze.Spectrums.convert_integral import convert_energy

# %%
import pandas as pd

# %%
df = pd.read_csv('../../.old/data/5555_eventos-edit.csv', index_col=0).iloc[:, :5555]
df
# Out:
#       event_0  event_1  event_2  event_3  event_4  event_5  event_6  event_7  \
# 0        56.0     56.0     56.0     53.0     55.0     55.0     54.0     54.0
# 1        55.0     55.0     55.0     53.0     55.0     55.0     54.0     54.0
# 2        53.0     53.0     53.0     51.0     53.0     53.0     55.0     55.0
# 3        53.0     53.0     53.0     52.0     53.0     53.0     54.0     54.0
# 4        54.0     54.0     54.0     53.0     55.0     55.0     55.0     55.0
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 2495     53.0     53.0     53.0     54.0     55.0     55.0     22.0     22.0
# 2496     55.0     55.0     55.0     54.0     56.0     56.0     14.0     14.0
# 2497     52.0     52.0     52.0     53.0     53.0     53.0     37.0     37.0
# 2498     52.0     52.0     52.0     53.0     54.0     54.0     51.0     51.0
# 2499     53.0     53.0     53.0     52.0     55.0     55.0     47.0     47.0
#
#       event_8  event_9  ...  event_5545  event_5546  event_5547  event_5548  \
# 0        54.0     54.0  ...        54.0        54.0        53.0        53.0
# 1        54.0     54.0  ...        52.0        52.0        52.0        52.0
# 2        55.0     55.0  ...        53.0        53.0        53.0        53.0
# 3        54.0     54.0  ...        53.0        53.0        53.0        53.0
# 4        55.0     55.0  ...        51.0        51.0        53.0        53.0
# ...       ...      ...  ...         ...         ...         ...         ...
# 2495     22.0     22.0  ...        54.0        54.0        50.0        50.0
# 2496     14.0     14.0  ...        50.0        50.0        51.0        51.0
# 2497     37.0     37.0  ...        53.0        53.0        51.0        51.0
# 2498     51.0     51.0  ...        52.0        52.0        53.0        53.0
# 2499     47.0     47.0  ...        53.0        53.0        52.0        52.0
#
#       event_5549  event_5550  event_5551  event_5552  event_5553  event_5554
# 0           51.0        51.0        51.0        51.0        51.0        51.0
# 1           52.0        51.0        51.0        51.0        51.0        51.0
# 2           50.0        55.0        55.0        55.0        55.0        55.0
# 3           50.0        55.0        55.0        55.0        55.0        55.0
# 4           52.0        54.0        54.0        54.0        54.0        54.0
# ...          ...         ...         ...         ...         ...         ...
# 2495        50.0        52.0        52.0        52.0        52.0        52.0
# 2496        53.0        51.0        51.0        51.0        51.0        51.0
# 2497        53.0        52.0        52.0        52.0        52.0        52.0
# 2498        52.0        52.0        52.0        52.0        52.0        52.0
# 2499        52.0        54.0        54.0        54.0        54.0        54.0
#
# [2500 rows x 5555 columns]

# %%
peaks, problems = peaks_muon_decay(df, -40)
peaks
# Out:
# C:\Users\jhapr\Documents\GitHub\mudecay\MuonDecay\data_analyze\FindPeaks\peaks.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   Peaks[event.name] = peaks
# C:\Users\jhapr\Documents\GitHub\mudecay\MuonDecay\data_analyze\FindPeaks\peaks.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   problems[event.name] = [f'peaks quantity ({len(x_peaks)})']
#             peak_X0  peak_X1  peak_Y0  peak_Y1
# event_0        94.0   1111.0   -127.0   -127.0
# event_1        94.0   1111.0   -127.0   -127.0
# event_2        94.0   1111.0   -127.0   -127.0
# event_3        94.0    322.0   -127.0   -127.0
# event_6        94.0   2491.0    -88.0   -127.0
# ...             ...      ...      ...      ...
# event_5545     94.0    754.0   -127.0   -127.0
# event_5546     94.0    754.0   -127.0   -127.0
# event_5547     94.0    527.0   -108.0    -94.0
# event_5548     94.0    527.0   -108.0    -94.0
# event_5549     94.0    274.0   -127.0    -95.0
#
# [3765 rows x 4 columns]

# %%
contours_0, contours_1, problems = contours_muon_decay(df, peaks)
contours_0
# Out:
# C:\Users\jhapr\Documents\GitHub\mudecay\MuonDecay\data_analyze\Spectrums\contours.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   contours_0[ event.name ] = pulse_0
# C:\Users\jhapr\Documents\GitHub\mudecay\MuonDecay\data_analyze\Spectrums\contours.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   contours_1[ event.name ] = pulse_1
#     event_0  event_1  event_2  event_3  event_10  event_11  event_12  \
# 0      53.0     53.0     53.0     53.0      55.0      54.0      54.0
# 1      54.0     54.0     54.0     53.0      54.0      53.0      51.0
# 2      51.0     51.0     51.0     55.0      53.0      53.0      54.0
# 3      52.0     52.0     52.0     52.0      53.0      52.0      54.0
# 4      55.0     55.0     55.0     52.0      53.0      51.0      52.0
# 5      53.0     53.0     53.0     54.0      54.0      54.0      53.0
# 6      54.0     54.0     54.0     55.0      55.0      52.0      53.0
# 7      52.0     52.0     52.0     53.0      51.0      53.0      53.0
# 8      22.0     22.0     22.0     20.0      49.0      51.0      45.0
# 9     -95.0    -95.0    -95.0   -105.0     -21.0      -7.0     -20.0
# 10   -127.0   -127.0   -127.0   -127.0    -127.0    -127.0    -108.0
# 11    -56.0    -56.0    -56.0    -54.0    -127.0    -127.0     -80.0
# 12     18.0     18.0     18.0      7.0     -99.0    -109.0      -2.0
# 13     39.0     39.0     39.0     27.0       8.0       7.0      30.0
# 14     29.0     29.0     29.0     21.0      21.0      25.0      29.0
# 15     30.0     30.0     30.0     29.0       6.0       7.0      30.0
# 16     49.0     49.0     49.0     47.0      20.0      18.0      43.0
# 17     51.0     51.0     51.0     46.0      42.0      45.0      51.0
# 18     46.0     46.0     46.0     43.0      44.0      49.0      47.0
# 19     43.0     43.0     43.0     44.0      42.0      40.0      43.0
# 20     51.0     51.0     51.0     47.0      39.0      39.0      48.0
# 21     55.0     55.0     55.0     52.0      50.0      46.0      53.0
# 22     50.0     50.0     50.0     47.0      54.0      53.0      51.0
# 23     47.0     47.0     47.0     53.0      48.0      49.0      48.0
# 24     55.0     55.0     55.0     54.0      49.0      47.0      51.0
#
#     event_13  event_14  event_15  ...  event_5534  event_5535  event_5540  \
# 0       54.0      54.0      55.0  ...        52.0        52.0        53.0
# 1       51.0      55.0      53.0  ...        52.0        52.0        51.0
# 2       54.0      52.0      49.0  ...        53.0        53.0        53.0
# 3       54.0      53.0      55.0  ...        53.0        53.0        50.0
# 6         53.0
# 7         52.0
# 8         42.0
# 9        -43.0
# 10      -127.0
# 11      -100.0
# 12       -18.0
# 13        22.0
# 14        27.0
# 15        28.0
# 16        38.0
# 17        49.0
# 18        48.0
# 19        44.0
# 20        46.0
# 21        50.0
# 22        52.0
# 23        50.0
# 24        51.0
#
# [25 rows x 3758 columns]

# %%
integral_0 = integral_rectangle_df(contours_0)
integral_1 = integral_rectangle_df(contours_1)
integral_1
# Out:
#                 0
# event_0     761.0
# event_1     761.0
# event_2     761.0
# event_3     540.0
# event_10    515.0
# ...           ...
# event_5545  547.0
# event_5546  547.0
# event_5547  803.0
# event_5548  803.0
# event_5549  834.0
#
# [3758 rows x 1 columns]

# %%
integrais = pd.concat([integral_0, integral_1], axis=1)
integrais.columns = ['integral_0', 'integral_1']
integrais
# Out:
#             integral_0  integral_1
# event_0          731.0       761.0
# event_1          731.0       761.0
# event_2          731.0       761.0
# event_3          678.0       540.0
# event_10         526.0       515.0
# ...                ...         ...
# event_5545       565.0       547.0
# event_5546       565.0       547.0
# event_5547       822.0       803.0
# event_5548       822.0       803.0
# event_5549       679.0       834.0
#
# [3758 rows x 2 columns]

# %%
sns.histplot( integrais.query('integral_0 < integral_1') )
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

bins='auto'

energy_0   = -1*convert_energy(integral_0)
energy_1   = -1*convert_energy(integral_1)

# Main plot
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(30,20))
fig.suptitle(f'Espectros de pico e carga; {peaks.shape[0]} events', fontsize=18)

# Fig 1: peaks_0
sns.histplot( peaks['peak_Y0'], ax=axes[0,0], color='orange', bins=bins )
axes[0,0].set_title(f'Espectro de picos')
axes[0,0].set_xlabel('peak (mV)')

# Fig 2: energy_0
sns.histplot( energy_0, ax=axes[0,1], color='blue', bins=bins )
axes[0,1].set_title(f'Espectro de carga')
axes[0,1].set_xlabel('energy (MeV)')

# #Fig 3: energy_0 x peaks_0
# axes[0,2].scatter( energy_0 , peaks['peak_Y0'] , color='green' )
# axes[0,2].set_title(f'picos X energia')
# axes[0,2].set_ylabel(f'peaks (mV)')
# # axes[0,2].set_xlabel(f'charge (pC)')
# axes[0,2].set_xlabel(f'energy (MeV)')

# Fig 4: peaks_1
sns.histplot( peaks['peak_Y1'], ax=axes[1,0], color='orange', bins=bins )
axes[1,0].set_title(f'Espectro de picos')
axes[1,0].set_xlabel('peak (mV)')

# Fig 5: energy_1
sns.histplot( energy_1, ax=axes[1,1], color='blue', bins=bins )
axes[1,1].set_title(f'Espectro de carga')
# axes[1,1].set_xlabel('charge (pC)')
axes[1,1].set_xlabel('energy (MeV)')

# #Fig 6: energy_1 x peaks_1
# axes[1,2].scatter( energy_1 , peaks['peak_Y1'] , color='green' )
# axes[1,2].set_title(f'picos X energia')
# axes[1,2].set_ylabel(f'peaks (mV)')
# # axes[1,2].set_xlabel(f'charge (pC)')
# axes[1,2].set_xlabel(f'energy (MeV)')
# Out:
# Text(0.5, 0, 'energy (MeV)')

# %%
plt.show()
