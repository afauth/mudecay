# %%
path = '../documents/data/1619903113.1208823'
print(path)
# Out:
# ../documents/data/1619903113.1208823

# %%
from data_analyze.Analyze.plots import plots_SingleMuon

# %%
plots_SingleMuon(path=path)
