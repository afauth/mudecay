# %%
path = '../documents/data/1619835018.0260653'
print(path)
# Out:
# ../documents/data/1619835018.0260653

# %%
from data_analyze.Analyze.plots import plots_SingleMuon

# %%
plots_SingleMuon(path=path)
